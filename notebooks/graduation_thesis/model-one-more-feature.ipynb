# %%
import random
import datetime

import shap
import numpy as np
import pandas as pd
import xgboost as xgb
import seaborn as sns
import matplotlib.pyplot as plt
import category_encoders as ce

from xgboost import plot_importance
from xgboost.sklearn import XGBRegressor
from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor
from sklearn import neighbors
from sklearn.neural_network import MLPRegressor
from sklearn.svm import SVR

from joblib import dump, load
from sklearn import preprocessing
from sklearn import linear_model
from sklearn.feature_selection import RFECV
from sklearn.feature_selection import SelectKBest
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import learning_curve
from sklearn.feature_selection import f_regression, mutual_info_regression
from sklearn.metrics import mean_squared_error,mean_absolute_error, r2_score

from sklearn.model_selection import train_test_split



def read_data(path):
    '''读取数据'''
    try:
        data = pd.read_csv(path, engine='python', encoding='utf8')
        return data
    except FileNotFoundError:
        print('File not found. Please check the path and filename.')
        return None
    except Exception as e:
        print('An error occurred:', e)
        return None

def assess_metrics(truth,pred):
    '''MAE、MSE、RMSE、决定系数'''
    print('----')
    print('MAE: %.4f'%mean_absolute_error(truth,pred))
    print('MSE: %.4f'%mean_squared_error(truth,pred))
    print('RMSE: %.4f'%mean_squared_error(truth,pred,squared=False))
    print('R2: %.4f'%r2_score(truth,pred))
    return mean_squared_error(truth,pred,squared=False),r2_score(truth,pred)

def model_result(est,X_train_val, X_test, y_train_val, y_test):
    '''Train and test a model, and print the results'''
    # training
    y_train_pred = est.predict(X_train_val)
    print('train metrics')
    assess_metrics(y_train_val, y_train_pred)
    # test
    print('test metrics')
    y_test_pred = est.predict(X_test)
    RMSE, R2 = assess_metrics(y_test, y_test_pred)
    return RMSE, R2
def model_lineresult(est,model,year,X_train_val, X_test, y_train_val, y_test):
    '''Train and test a linear regression model, and print the results in a line'''
    date = datetime.datetime.now().strftime('%Y-%m-%d')
    # train and test
    y_train_pred = est.predict(X_train_val)
    y_test_pred = est.predict(X_test)
    print('{} {} {} 【Train_RMSE: {:.2f}, Train_R2: {:.2f}, Test_RMSE: {:.4f}, Test_R2: {:.2f}】'
          .format(date,year,model,mean_squared_error(y_train_val, y_train_pred,squared=False),r2_score(y_train_val, y_train_pred),
          mean_squared_error(y_test, y_test_pred,squared=False),r2_score(y_test, y_test_pred)))
    return mean_squared_error(y_test, y_test_pred,squared=False),r2_score(y_test, y_test_pred)

# %%
def yield_predictor(data, test_year=[2020], N=2, experiment = 'GDT', croptype = 'soybean', model = ['XGBoost'], verbose = 0,
                    tune_model = False, model_parameter=None, result = False, result_dir = '', feature_importance = False,
                    fea_eng = False,seed = 99,save_model=False, save_model_dir='', trend_n = 30,
                    importance_dir = '', feature_list = None, n_features = 200, 
                    metric_list = [],feature_name = [],feature_type = 'one_feature',col = None):
    '''Yield predictor
    Parameters:
    
    '''
    if feature_type == 'one_feature':
        print('feature name:',feature_name, 'seed:',seed, 'croptype:',croptype,' ','test_year:',test_year[0],' ','model:',model[0],' ',
          'experiment:',experiment,'n_feature：',n_features) 

        feature_name1 = ['sta_con','State','yield(t/ha)','Year','Value','GDT_trend_yield']+[feature_name]
        print(len(feature_name1)-6)
        data = data[feature_name1]
        print(data.columns.shape[0])
    else:
        print('feature name:',col, 'seed:',seed, 'croptype:',croptype,' ','test_year:',test_year[0],' ','model:',model[0],' ',
          'experiment:',experiment,'n_feature：',n_features) 
        feature_name1 = ['sta_con','State','yield(t/ha)','Year','Value','GDT_trend_yield']+feature_name
        print(len(feature_name1)-6)
        data = data[feature_name1]
        print(data.columns.shape[0])
        
        # 如果特征数量不足五百，则不管，特征数量超过五百，取前存在的五百个
        common_features = list(set(feature_list['feature']) & set(data.columns))
        n_common_features = len(common_features)

        if n_common_features > n_features:
            feature_name = feature_list.loc[feature_list['feature'].isin(common_features), 'feature'].iloc[:n_features].tolist()
        else:
            feature_name = feature_list.loc[feature_list['feature'].isin(common_features), 'feature'].tolist()
        
    # split train-validation and test data
    # testset
    data_test = data[data['Year'].isin(test_year)]
    # tra-val set
    data_train_val = data[data['Year'].isin([i for i in range(test_year[0]-N,test_year[0])])]
    # split input and output
    y_train_val = data_train_val['yield(t/ha)']
    y_test = data_test['yield(t/ha)']
    
    if experiment == 'GDT': # GDT
        # de-trend the yield using linear model
        yield_mean = data_train_val['yield(t/ha)'].mean()
        linear_m = linear_model.LinearRegression()
        
        data_train_val1 = data[data['Year'].isin([i for i in range(test_year[0]-trend_n,test_year[0])])]
        X99 = np.array(data_train_val1['Year']).reshape(-1,1)
        Y99 = np.array(data_train_val1['yield(t/ha)']).reshape(-1,1)

        linear_m.fit(X99, Y99)
        if linear_m.coef_[0,0]<0:
            yield_mean = data_train_val['yield(t/ha)'].mean()
        print('The foluma of de-trend the yield: yield_new = yield - {:.3f}×year + {:.3f} - ({:.3f})'
              .format(linear_m.coef_[0,0],yield_mean,linear_m.intercept_[0]))

        # de-trend data_train_val yield 
        data1 = data_train_val.copy()
        data1.loc[:,'yield(t/ha)_fix'] = data_train_val['yield(t/ha)'] - linear_m.coef_[0] * data_train_val['Year'] + yield_mean - linear_m.intercept_
        data1 = data1.drop(['yield(t/ha)'], axis = 1).rename({'yield(t/ha)_fix':'yield(t/ha)'}, axis=1)
        data_train_val = data1
        # de-trend data_test yield 
        data1 = data_test.copy()
        data1.loc[:,'yield(t/ha)_fix'] = data_test['yield(t/ha)'] - linear_m.coef_[0] * data_test['Year'] + yield_mean - linear_m.intercept_

        data1 = data1.drop(['yield(t/ha)'], axis = 1).rename({'yield(t/ha)_fix':'yield(t/ha)'}, axis=1)
        data_test = data1
        y_train_val = data_train_val['yield(t/ha)']
        y_test = data_test['yield(t/ha)']
        
        X_train_val = data_train_val.drop(['sta_con','State','yield(t/ha)','Year','Value','GDT_trend_yield'], axis=1)# 
        X_test = data_test.drop(['sta_con','State','yield(t/ha)','Year','Value','GDT_trend_yield'], axis=1) # 'Value'
    else: None
 
    # Scale numeric features
    columns_to_scale = X_train_val.columns.tolist()
    std_scaler = preprocessing.StandardScaler().fit(X_train_val[columns_to_scale])
    X_train_val.loc[:,columns_to_scale] = std_scaler.transform(X_train_val[columns_to_scale])
    X_test.loc[:,columns_to_scale] = std_scaler.transform(X_test[columns_to_scale])
    
    # 模型选择 ['LR','RF','KNN','ANN','XGBoost','SVR']
    if 'XGBoost'in model:
        est = XGBRegressor(max_depth= 7,learning_rate=0.09,n_estimators=700,seed=seed,objective= 'reg:gamma',
                           min_child_weight= 3,colsample_bytree=0.7, subsample= 0.8,reg_alpha= 0.1)# mse learning_rate=0.05,n_estimators=1000
        est.fit(X_train_val,y_train_val)
        if verbose == 0:
            RMSE,R2 = model_lineresult(est,'XGBoost',test_year,X_train_val, X_test, y_train_val, y_test)
        else:
            RMSE,R2 = model_result(est,X_train_val, X_test, y_train_val, y_test)
    else: 
        None

    metric_list.append([col,seed, croptype, test_year[0], model[0], N,  RMSE,R2])
                                 
    if result:
        # get the yield and pred
        pred = est.predict(X_test)
        if croptype == 'maize':
            result = pd.concat([data.loc[y_test.index,['sta_con', 'yield(t/ha)']], pd.DataFrame(pred,index = y_test.index,columns=['pred'])],axis=1)
        else:
            result = pd.concat([data.loc[y_test.index,['sta_con', 'yield(t/ha)']], pd.DataFrame(pred,index = y_test.index,columns=['pred'])],axis=1)
        if experiment == 'GDT':
            result.loc[:,'pred'] = result.loc[:,'pred']+linear_m.coef_[0] * data_test['Year'] - yield_mean + linear_m.intercept_
        # result.loc[:,['yield','pred']] = result.loc[:,['yield','pred']]*62.719012*0.001
        result.loc[:,'residual'] =  result.loc[:,'pred'] - result.loc[:,'yield(t/ha)']
        if feature_type == 'one_feature':
            result.to_csv(result_dir +croptype+'/'+feature_name+str(seed) + '_' + str(test_year[0]) + '_' + model[0] + '_' + 'exp'+str(experiment)+'_N'+str(N)+'_预测结果.csv',header=True)
            # print('Results have been saved！')
        else:
            result.to_csv(result_dir +croptype+'/'+str(col)+str(seed) + '_' + str(test_year[0]) + '_' + model[0] + '_' + 'exp'+str(experiment)+'_N'+str(N)+'_预测结果.csv',header=True)
    
    shap_values = None

    return None,None,metric_list

# %% [markdown]
# ### 多因子特征结果-大豆

# %%
# 2014-2021，每10年预测一年
data = read_data('D:/毕业大论文/数据/input_soybean_rename.csv')
featurelist = read_data('D:/毕业大论文/结果/SHAP值结果/soybean/average_feature_importance.csv')

# %%
# 特征组合列表
crop_type = 'soybean'
all_features = data.columns.tolist()
more_feature_list = []
RS_sublist = ['NDVI_','EVI_','LSWI_','GCVI_', 'RVI_','SAVI_','WDRVI_','Fpar_', 'LAI_','ET_','LE_','LST_Day_','LST_Night_','Red_','Nir_','Blue_','Green_',
'Nir1_','Swir1_','Swir2_',]
time_list = ['Mid Mar.','Late Mar.','Early Apr.','Mid Apr.','Late Apr.','Early May.','Mid May.','Late May.','Early Jun.','Mid Jun.','Late Jun.','Early Jul.',
                 'Mid Jul.','Late Jul.','Early Aug.','Mid Aug.','Late Aug.','Early Sep.','Mid Sep.','Late Sep.','Early Oct.','Mid Oct.','Late Oct.','Early Nov.',
                 'Mid Nov.','Late Nov.','Early Dec.']
WE_sublist = ['SPI14d_','SPI30d_','SPI90d_','EDDI14d_','EDDI30d_','EDDI90d_','SPEI14d_','SPEI30d_','SPEI90d_','PDSI_','Palmer Z_','Precipitation_','Temp_',
'Humidity_','Pressure_', 'Shortwave_','Longwave_']
phology_list_soybean = ['Planting','Emerging','Blooming','Podding','Dropping leaves','Harvest',]
phology_list_maize = ['Planting','Emerging','Silking','Dough','Dent','Maturity','Harvest',]

#（1）遥感卫星
RS = []
for i in RS_sublist:
    for time in time_list:
        RS.append(i+time)
more_feature_list.append(RS)

#（2）遥感卫星+气候变量
WE = []
for i in WE_sublist:
    for time in time_list:
        WE.append(i+time)
more_feature_list.append(RS+WE)

# 遥感卫星+气候变量+物候信息
PH = []
for i in [element for element in RS_sublist+WE_sublist if element not in ['Precipitation_','Humidity_','Pressure_',]]:
    if crop_type == 'soybean':
        for phology in phology_list_soybean:
            PH.append(i+phology)
    else:
        for phology in phology_list_maize:
            PH.append(i+phology)
more_feature_list.append(RS+WE+PH)

#（4）遥感卫星+气候变量+物候信息+位置编码
LO = ['IL','IN','IA','KS','MI','MN','MO','NE','ND','OH','SD','WI','Longitude', 'Latitude',]
more_feature_list.append(RS+WE+PH+LO)

#（5）遥感卫星+气候变量+物候信息+位置编码+土壤性质
SO = ['AREA_Irrigated', 'AREA', 'PIC', 'CaCO3', 'CEC', 'Drainage', 'EC', 'I_class', 'N_class', 'Max_OM', 'PAWS', 'pH', 'SAR', 'Texture', 'Sand', 'Silt', 'Clay',]
more_feature_list.append(RS+WE+PH+LO+SO)

# print(len(more_feature_list))
# print(more_feature_list)
# more_feature_list = one_feature_list+['EVI_Podding','Latitude','PAWS','SPI30d_Early Sep.','PIC']
# one_feature_list

# %%
metric_list = []
for i in range(5):
    for year in range(2014,2022):
            shap_values_train,shap_values_test,metric_list = yield_predictor(data, test_year=[year], N=10, experiment = 'GDT', croptype = crop_type, model = ['XGBoost'], verbose = 0,
                        result = True, seed = 99, feature_list = featurelist, n_features = 500, metric_list = metric_list, 
                        result_dir = 'D:/毕业大论文/结果/特征组合结果/多因子结果/',feature_name = more_feature_list[i],feature_type = 'more_feature',col = i)
        
name = ['feature','seed', 'croptype', 'test_year', 'model', 'Train_years', 'RMSE', 'R2']
print(metric_list)
metric_df = pd.DataFrame(columns = name, data=metric_list)
metric_df.to_csv('D:/毕业大论文/结果/特征组合结果/多因子结果/' + crop_type +'_预测指标.csv',header=True)
# Out:
# feature name: 0 seed: 99 croptype: soybean   test_year: 2014   model: XGBoost   experiment: GDT n_feature： 500
# 540
# 546
# The foluma of de-trend the yield: yield_new = yield - 0.030×year + 2.915 - (-58.235)
# 2023-03-14 [2014] XGBoost 【Train_RMSE: 0.02, Train_R2: 1.00, Test_RMSE: 0.2875, Test_R2: 0.72】
# feature name: 0 seed: 99 croptype: soybean   test_year: 2015   model: XGBoost   experiment: GDT n_feature： 500
# 540
# 546
# The foluma of de-trend the yield: yield_new = yield - 0.030×year + 2.962 - (-57.658)
# 2023-03-14 [2015] XGBoost 【Train_RMSE: 0.02, Train_R2: 1.00, Test_RMSE: 0.3095, Test_R2: 0.70】
# feature name: 0 seed: 99 croptype: soybean   test_year: 2016   model: XGBoost   experiment: GDT n_feature： 500
# 540
# 546
# The foluma of de-trend the yield: yield_new = yield - 0.033×year + 3.003 - (-63.403)
# 2023-03-14 [2016] XGBoost 【Train_RMSE: 0.02, Train_R2: 1.00, Test_RMSE: 0.3933, Test_R2: 0.37】
# feature name: 0 seed: 99 croptype: soybean   test_year: 2017   model: XGBoost   experiment: GDT n_feature： 500
# 540
# 546
# The foluma of de-trend the yield: yield_new = yield - 0.038×year + 3.073 - (-72.756)
# 2023-03-14 [2017] XGBoost 【Train_RMSE: 0.02, Train_R2: 1.00, Test_RMSE: 0.2911, Test_R2: 0.75】
# feature name: 0 seed: 99 croptype: soybean   test_year: 2018   model: XGBoost   experiment: GDT n_feature： 500
# 540
# 546
# The foluma of de-trend the yield: yield_new = yield - 0.040×year + 3.124 - (-78.120)
# 2023-03-14 [2018] XGBoost 【Train_RMSE: 0.02, Train_R2: 1.00, Test_RMSE: 0.3825, Test_R2: 0.67】
# feature name: 0 seed: 99 croptype: soybean   test_year: 2019   model: XGBoost   experiment: GDT n_feature： 500
# 540
# 546
# The foluma of de-trend the yield: yield_new = yield - 0.039×year + 3.204 - (-74.658)
# 2023-03-14 [2019] XGBoost 【Train_RMSE: 0.02, Train_R2: 1.00, Test_RMSE: 0.3039, Test_R2: 0.71】
# feature name: 0 seed: 99 croptype: soybean   test_year: 2020   model: XGBoost   experiment: GDT n_feature： 500
# 540
# 546
# The foluma of de-trend the yield: yield_new = yield - 0.038×year + 3.226 - (-72.845)
# 2023-03-14 [2020] XGBoost 【Train_RMSE: 0.02, Train_R2: 1.00, Test_RMSE: 0.3274, Test_R2: 0.72】
# feature name: 0 seed: 99 croptype: soybean   test_year: 2021   model: XGBoost   experiment: GDT n_feature： 500
# 540
# 546
# The foluma of de-trend the yield: yield_new = yield - 0.039×year + 3.266 - (-75.237)
# 2023-03-14 [2021] XGBoost 【Train_RMSE: 0.02, Train_R2: 1.00, Test_RMSE: 0.3968, Test_R2: 0.79】
# feature name: 1 seed: 99 croptype: soybean   test_year: 2014   model: XGBoost   experiment: GDT n_feature： 500
# 999
# 1005
# The foluma of de-trend the yield: yield_new = yield - 0.030×year + 2.915 - (-58.235)
# 2023-03-14 [2014] XGBoost 【Train_RMSE: 0.02, Train_R2: 1.00, Test_RMSE: 0.2785, Test_R2: 0.74】
# feature name: 1 seed: 99 croptype: soybean   test_year: 2015   model: XGBoost   experiment: GDT n_feature： 500
# 999
# 1005
# The foluma of de-trend the yield: yield_new = yield - 0.030×year + 2.962 - (-57.658)
# 2023-03-14 [2015] XGBoost 【Train_RMSE: 0.02, Train_R2: 1.00, Test_RMSE: 0.3019, Test_R2: 0.71】
# feature name: 1 seed: 99 croptype: soybean   test_year: 2016   model: XGBoost   experiment: GDT n_feature： 500
# 999
# 1005
# The foluma of de-trend the yield: yield_new = yield - 0.033×year + 3.003 - (-63.403)
# 2023-03-14 [2016] XGBoost 【Train_RMSE: 0.02, Train_R2: 1.00, Test_RMSE: 0.3727, Test_R2: 0.44】
# feature name: 1 seed: 99 croptype: soybean   test_year: 2017   model: XGBoost   experiment: GDT n_feature： 500
# 999
# 1005
# The foluma of de-trend the yield: yield_new = yield - 0.038×year + 3.073 - (-72.756)
# 2023-03-14 [2017] XGBoost 【Train_RMSE: 0.02, Train_R2: 1.00, Test_RMSE: 0.2893, Test_R2: 0.75】
# feature name: 1 seed: 99 croptype: soybean   test_year: 2018   model: XGBoost   experiment: GDT n_feature： 500
# 999
# 1005
# The foluma of de-trend the yield: yield_new = yield - 0.040×year + 3.124 - (-78.120)
# 2023-03-14 [2018] XGBoost 【Train_RMSE: 0.02, Train_R2: 1.00, Test_RMSE: 0.3631, Test_R2: 0.70】
# feature name: 1 seed: 99 croptype: soybean   test_year: 2019   model: XGBoost   experiment: GDT n_feature： 500
# 999
# 1005
# The foluma of de-trend the yield: yield_new = yield - 0.039×year + 3.204 - (-74.658)
# 2023-03-14 [2019] XGBoost 【Train_RMSE: 0.02, Train_R2: 1.00, Test_RMSE: 0.3150, Test_R2: 0.69】
# feature name: 1 seed: 99 croptype: soybean   test_year: 2020   model: XGBoost   experiment: GDT n_feature： 500
# 999
# 1005
# The foluma of de-trend the yield: yield_new = yield - 0.038×year + 3.226 - (-72.845)
# 2023-03-14 [2020] XGBoost 【Train_RMSE: 0.02, Train_R2: 1.00, Test_RMSE: 0.3374, Test_R2: 0.71】
# feature name: 1 seed: 99 croptype: soybean   test_year: 2021   model: XGBoost   experiment: GDT n_feature： 500
# 999
# 1005
# The foluma of de-trend the yield: yield_new = yield - 0.039×year + 3.266 - (-75.237)
# 2023-03-14 [2021] XGBoost 【Train_RMSE: 0.02, Train_R2: 1.00, Test_RMSE: 0.3628, Test_R2: 0.83】
# feature name: 2 seed: 99 croptype: soybean   test_year: 2014   model: XGBoost   experiment: GDT n_feature： 500
# 1203
# 1209
# The foluma of de-trend the yield: yield_new = yield - 0.030×year + 2.915 - (-58.235)
# 2023-03-14 [2014] XGBoost 【Train_RMSE: 0.02, Train_R2: 1.00, Test_RMSE: 0.2768, Test_R2: 0.74】
# feature name: 2 seed: 99 croptype: soybean   test_year: 2015   model: XGBoost   experiment: GDT n_feature： 500
# 1203
# 1209
# The foluma of de-trend the yield: yield_new = yield - 0.030×year + 2.962 - (-57.658)
# 2023-03-14 [2015] XGBoost 【Train_RMSE: 0.02, Train_R2: 1.00, Test_RMSE: 0.2928, Test_R2: 0.73】
# feature name: 2 seed: 99 croptype: soybean   test_year: 2016   model: XGBoost   experiment: GDT n_feature： 500
# 1203
# 1209
# The foluma of de-trend the yield: yield_new = yield - 0.033×year + 3.003 - (-63.403)
# 2023-03-14 [2016] XGBoost 【Train_RMSE: 0.02, Train_R2: 1.00, Test_RMSE: 0.3725, Test_R2: 0.44】
# feature name: 2 seed: 99 croptype: soybean   test_year: 2017   model: XGBoost   experiment: GDT n_feature： 500
# 1203
# 1209
# The foluma of de-trend the yield: yield_new = yield - 0.038×year + 3.073 - (-72.756)
# 2023-03-14 [2017] XGBoost 【Train_RMSE: 0.02, Train_R2: 1.00, Test_RMSE: 0.2763, Test_R2: 0.77】
# feature name: 2 seed: 99 croptype: soybean   test_year: 2018   model: XGBoost   experiment: GDT n_feature： 500
# 1203
# 1209
# The foluma of de-trend the yield: yield_new = yield - 0.040×year + 3.124 - (-78.120)
# 2023-03-14 [2018] XGBoost 【Train_RMSE: 0.02, Train_R2: 1.00, Test_RMSE: 0.3336, Test_R2: 0.75】
# feature name: 2 seed: 99 croptype: soybean   test_year: 2019   model: XGBoost   experiment: GDT n_feature： 500
# 1203
# 1209
# The foluma of de-trend the yield: yield_new = yield - 0.039×year + 3.204 - (-74.658)
# 2023-03-14 [2019] XGBoost 【Train_RMSE: 0.02, Train_R2: 1.00, Test_RMSE: 0.3241, Test_R2: 0.67】
# feature name: 2 seed: 99 croptype: soybean   test_year: 2020   model: XGBoost   experiment: GDT n_feature： 500
# 1203
# 1209
# The foluma of de-trend the yield: yield_new = yield - 0.038×year + 3.226 - (-72.845)
# 2023-03-14 [2020] XGBoost 【Train_RMSE: 0.02, Train_R2: 1.00, Test_RMSE: 0.3314, Test_R2: 0.72】
# feature name: 2 seed: 99 croptype: soybean   test_year: 2021   model: XGBoost   experiment: GDT n_feature： 500
# 1203
# 1209
# The foluma of de-trend the yield: yield_new = yield - 0.039×year + 3.266 - (-75.237)
# 2023-03-14 [2021] XGBoost 【Train_RMSE: 0.02, Train_R2: 1.00, Test_RMSE: 0.3577, Test_R2: 0.83】
# feature name: 3 seed: 99 croptype: soybean   test_year: 2014   model: XGBoost   experiment: GDT n_feature： 500
# 1217
# 1223
# The foluma of de-trend the yield: yield_new = yield - 0.030×year + 2.915 - (-58.235)
# 2023-03-15 [2014] XGBoost 【Train_RMSE: 0.01, Train_R2: 1.00, Test_RMSE: 0.2677, Test_R2: 0.76】
# feature name: 3 seed: 99 croptype: soybean   test_year: 2015   model: XGBoost   experiment: GDT n_feature： 500
# 1217
# 1223
# The foluma of de-trend the yield: yield_new = yield - 0.030×year + 2.962 - (-57.658)
# 2023-03-15 [2015] XGBoost 【Train_RMSE: 0.01, Train_R2: 1.00, Test_RMSE: 0.2751, Test_R2: 0.76】
# feature name: 3 seed: 99 croptype: soybean   test_year: 2016   model: XGBoost   experiment: GDT n_feature： 500
# 1217
# 1223
# The foluma of de-trend the yield: yield_new = yield - 0.033×year + 3.003 - (-63.403)
# 2023-03-15 [2016] XGBoost 【Train_RMSE: 0.01, Train_R2: 1.00, Test_RMSE: 0.3728, Test_R2: 0.44】
# feature name: 3 seed: 99 croptype: soybean   test_year: 2017   model: XGBoost   experiment: GDT n_feature： 500
# 1217
# 1223
# The foluma of de-trend the yield: yield_new = yield - 0.038×year + 3.073 - (-72.756)
# 2023-03-15 [2017] XGBoost 【Train_RMSE: 0.01, Train_R2: 1.00, Test_RMSE: 0.2723, Test_R2: 0.78】
# feature name: 3 seed: 99 croptype: soybean   test_year: 2018   model: XGBoost   experiment: GDT n_feature： 500
# 1217
# 1223
# The foluma of de-trend the yield: yield_new = yield - 0.040×year + 3.124 - (-78.120)
# 2023-03-15 [2018] XGBoost 【Train_RMSE: 0.01, Train_R2: 1.00, Test_RMSE: 0.3550, Test_R2: 0.71】
# feature name: 3 seed: 99 croptype: soybean   test_year: 2019   model: XGBoost   experiment: GDT n_feature： 500
# 1217
# 1223
# The foluma of de-trend the yield: yield_new = yield - 0.039×year + 3.204 - (-74.658)
# 2023-03-15 [2019] XGBoost 【Train_RMSE: 0.01, Train_R2: 1.00, Test_RMSE: 0.3056, Test_R2: 0.71】
# feature name: 3 seed: 99 croptype: soybean   test_year: 2020   model: XGBoost   experiment: GDT n_feature： 500
# 1217
# 1223
# The foluma of de-trend the yield: yield_new = yield - 0.038×year + 3.226 - (-72.845)
# 2023-03-15 [2020] XGBoost 【Train_RMSE: 0.01, Train_R2: 1.00, Test_RMSE: 0.3303, Test_R2: 0.72】
# feature name: 3 seed: 99 croptype: soybean   test_year: 2021   model: XGBoost   experiment: GDT n_feature： 500
# 1217
# 1223
# The foluma of de-trend the yield: yield_new = yield - 0.039×year + 3.266 - (-75.237)
# 2023-03-15 [2021] XGBoost 【Train_RMSE: 0.01, Train_R2: 1.00, Test_RMSE: 0.3644, Test_R2: 0.83】
# feature name: 4 seed: 99 croptype: soybean   test_year: 2014   model: XGBoost   experiment: GDT n_feature： 500
# 1234
# 1240
# The foluma of de-trend the yield: yield_new = yield - 0.030×year + 2.915 - (-58.235)
# 2023-03-15 [2014] XGBoost 【Train_RMSE: 0.01, Train_R2: 1.00, Test_RMSE: 0.2596, Test_R2: 0.78】
# feature name: 4 seed: 99 croptype: soybean   test_year: 2015   model: XGBoost   experiment: GDT n_feature： 500
# 1234
# 1240
# The foluma of de-trend the yield: yield_new = yield - 0.030×year + 2.962 - (-57.658)
# 2023-03-15 [2015] XGBoost 【Train_RMSE: 0.01, Train_R2: 1.00, Test_RMSE: 0.2660, Test_R2: 0.78】
# feature name: 4 seed: 99 croptype: soybean   test_year: 2016   model: XGBoost   experiment: GDT n_feature： 500
# 1234
# 1240
# The foluma of de-trend the yield: yield_new = yield - 0.033×year + 3.003 - (-63.403)
# 2023-03-15 [2016] XGBoost 【Train_RMSE: 0.01, Train_R2: 1.00, Test_RMSE: 0.3639, Test_R2: 0.46】
# feature name: 4 seed: 99 croptype: soybean   test_year: 2017   model: XGBoost   experiment: GDT n_feature： 500
# 1234
# 1240
# The foluma of de-trend the yield: yield_new = yield - 0.038×year + 3.073 - (-72.756)
# 2023-03-15 [2017] XGBoost 【Train_RMSE: 0.01, Train_R2: 1.00, Test_RMSE: 0.2521, Test_R2: 0.81】
# feature name: 4 seed: 99 croptype: soybean   test_year: 2018   model: XGBoost   experiment: GDT n_feature： 500
# 1234
# 1240
# The foluma of de-trend the yield: yield_new = yield - 0.040×year + 3.124 - (-78.120)
# 2023-03-15 [2018] XGBoost 【Train_RMSE: 0.01, Train_R2: 1.00, Test_RMSE: 0.3176, Test_R2: 0.77】
# feature name: 4 seed: 99 croptype: soybean   test_year: 2019   model: XGBoost   experiment: GDT n_feature： 500
# 1234
# 1240
# The foluma of de-trend the yield: yield_new = yield - 0.039×year + 3.204 - (-74.658)
# 2023-03-15 [2019] XGBoost 【Train_RMSE: 0.01, Train_R2: 1.00, Test_RMSE: 0.2910, Test_R2: 0.73】
# feature name: 4 seed: 99 croptype: soybean   test_year: 2020   model: XGBoost   experiment: GDT n_feature： 500
# 1234
# 1240
# The foluma of de-trend the yield: yield_new = yield - 0.038×year + 3.226 - (-72.845)
# 2023-03-15 [2020] XGBoost 【Train_RMSE: 0.01, Train_R2: 1.00, Test_RMSE: 0.3114, Test_R2: 0.75】
# feature name: 4 seed: 99 croptype: soybean   test_year: 2021   model: XGBoost   experiment: GDT n_feature： 500
# 1234
# 1240
# The foluma of de-trend the yield: yield_new = yield - 0.039×year + 3.266 - (-75.237)
# 2023-03-15 [2021] XGBoost 【Train_RMSE: 0.01, Train_R2: 1.00, Test_RMSE: 0.3440, Test_R2: 0.84】
# [[0, 99, 'soybean', 2014, 'XGBoost', 10, 0.2875150552506383, 0.724699862108163], [0, 99, 'soybean', 2015, 'XGBoost', 10, 0.3095403184223938, 0.699829409855552], [0, 99, 'soybean', 2016, 'XGBoost', 10, 0.3933179112077311, 0.3740696137187671], [0, 99, 'soybean', 2017, 'XGBoost', 10, 0.29113398477225005, 0.747728702428293], [0, 99, 'soybean', 2018, 'XGBoost', 10, 0.3824951066313128, 0.6676366654702823], [0, 99, 'soybean', 2019, 'XGBoost', 10, 0.3039137429412728, 0.7096697484426411], [0, 99, 'soybean', 2020, 'XGBoost', 10, 0.3274208242218774, 0.7231626235056714], [0, 99, 'soybean', 2021, 'XGBoost', 10, 0.3967916430376531, 0.793357245331225], [1, 99, 'soybean', 2014, 'XGBoost', 10, 0.2785273056498341, 0.7416426605991338], [1, 99, 'soybean', 2015, 'XGBoost', 10, 0.3018658756603163, 0.7145291742701255], [1, 99, 'soybean', 2016, 'XGBoost', 10, 0.37271949987967035, 0.43791393776152243], [1, 99, 'soybean', 2017, 'XGBoost', 10, 0.2892938067793967, 0.7509076990258022], [1, 99, 'soybean', 2018, 'XGBoost', 10, 0.3631277134466367, 0.7004425461737401], [1, 99, 'soybean', 2019, 'XGBoost', 10, 0.315044177944948, 0.6880144150220905], [1, 99, 'soybean', 2020, 'XGBoost', 10, 0.33737906546634255, 0.7060669698066291], [1, 99, 'soybean', 2021, 'XGBoost', 10, 0.3627784381522349, 0.827265899588987], [2, 99, 'soybean', 2014, 'XGBoost', 10, 0.2768356427864466, 0.7447714473575278], [2, 99, 'soybean', 2015, 'XGBoost', 10, 0.2927886678365329, 0.7314394507895614], [2, 99, 'soybean', 2016, 'XGBoost', 10, 0.3725025437523843, 0.43856811616094193], [2, 99, 'soybean', 2017, 'XGBoost', 10, 0.2762915494014007, 0.7727953395186626], [2, 99, 'soybean', 2018, 'XGBoost', 10, 0.3336217311162304, 0.7471458979369232], [2, 99, 'soybean', 2019, 'XGBoost', 10, 0.3240536444021631, 0.6699152715660072], [2, 99, 'soybean', 2020, 'XGBoost', 10, 0.3314044538789594, 0.7163852512416495], [2, 99, 'soybean', 2021, 'XGBoost', 10, 0.35774420188708367, 0.832026660534573], [3, 99, 'soybean', 2014, 'XGBoost', 10, 0.2676907561666187, 0.7613551885798472], [3, 99, 'soybean', 2015, 'XGBoost', 10, 0.27514056000521475, 0.7628391911843099], [3, 99, 'soybean', 2016, 'XGBoost', 10, 0.3728480599474556, 0.4375261164389437], [3, 99, 'soybean', 2017, 'XGBoost', 10, 0.27231417044882994, 0.7792897440093186], [3, 99, 'soybean', 2018, 'XGBoost', 10, 0.35500054027118705, 0.7137013049153798], [3, 99, 'soybean', 2019, 'XGBoost', 10, 0.3055634801511668, 0.706509189733146], [3, 99, 'soybean', 2020, 'XGBoost', 10, 0.33026756554185094, 0.7183278035002385], [3, 99, 'soybean', 2021, 'XGBoost', 10, 0.3644441243107019, 0.8256760513484599], [4, 99, 'soybean', 2014, 'XGBoost', 10, 0.25963431051819985, 0.7755035825744716], [4, 99, 'soybean', 2015, 'XGBoost', 10, 0.26598601048314335, 0.7783583982103689], [4, 99, 'soybean', 2016, 'XGBoost', 10, 0.3638857221310502, 0.46424205777394545], [4, 99, 'soybean', 2017, 'XGBoost', 10, 0.25207913391440995, 0.8108720009469312], [4, 99, 'soybean', 2018, 'XGBoost', 10, 0.31762936500827244, 0.7708063223835793], [4, 99, 'soybean', 2019, 'XGBoost', 10, 0.29095061001210687, 0.7339090181526564], [4, 99, 'soybean', 2020, 'XGBoost', 10, 0.3114313803812164, 0.749540867790504], [4, 99, 'soybean', 2021, 'XGBoost', 10, 0.3440190971162169, 0.8446682437855862]]

# %% [markdown]
# ### 多因子特征结果-玉米

# %%
# 2014-2021，每10年预测一年
data = read_data('D:/毕业大论文/数据/input_maize_rename.csv')
featurelist = read_data('D:/毕业大论文/结果/SHAP值结果/maize/average_feature_importance.csv')

# %%
# 特征组合列表
crop_type = 'maize'
all_features = data.columns.tolist()
more_feature_list = []
RS_sublist = ['NDVI_','EVI_','LSWI_','GCVI_', 'RVI_','SAVI_','WDRVI_','Fpar_', 'LAI_','ET_','LE_','LST_Day_','LST_Night_','Red_','Nir_','Blue_','Green_',
'Nir1_','Swir1_','Swir2_',]
time_list = ['Mid Mar.','Late Mar.','Early Apr.','Mid Apr.','Late Apr.','Early May.','Mid May.','Late May.','Early Jun.','Mid Jun.','Late Jun.','Early Jul.',
                 'Mid Jul.','Late Jul.','Early Aug.','Mid Aug.','Late Aug.','Early Sep.','Mid Sep.','Late Sep.','Early Oct.','Mid Oct.','Late Oct.','Early Nov.',
                 'Mid Nov.','Late Nov.','Early Dec.']
WE_sublist = ['SPI14d_','SPI30d_','SPI90d_','EDDI14d_','EDDI30d_','EDDI90d_','SPEI14d_','SPEI30d_','SPEI90d_','PDSI_','Palmer Z_','Precipitation_','Temp_',
'Humidity_','Pressure_', 'Shortwave_','Longwave_']
phology_list_soybean = ['Planting','Emerging','Blooming','Podding','Dropping leaves','Harvest',]
phology_list_maize = ['Planting','Emerging','Silking','Dough','Dent','Maturity','Harvest',]

#（1）遥感卫星
RS = []
for i in RS_sublist:
    for time in time_list:
        RS.append(i+time)
more_feature_list.append(RS)

#（2）遥感卫星+气候变量
WE = []
for i in WE_sublist:
    for time in time_list:
        WE.append(i+time)
more_feature_list.append(RS+WE)

# 遥感卫星+气候变量+物候信息
PH = []
for i in [element for element in RS_sublist+WE_sublist if element not in ['Precipitation_','Humidity_','Pressure_',]]:
    if crop_type == 'soybean':
        for phology in phology_list_soybean:
            PH.append(i+phology)
    else:
        for phology in phology_list_maize:
            PH.append(i+phology)
more_feature_list.append(RS+WE+PH)

#（4）遥感卫星+气候变量+物候信息+位置编码
LO = ['IL','IN','IA','KS','MI','MN','MO','NE','ND','OH','SD','WI','Longitude', 'Latitude',]
more_feature_list.append(RS+WE+PH+LO)

#（5）遥感卫星+气候变量+物候信息+位置编码+土壤性质
SO = ['AREA_Irrigated', 'AREA', 'PIC', 'CaCO3', 'CEC', 'Drainage', 'EC', 'I_class', 'N_class', 'Max_OM', 'PAWS', 'pH', 'SAR', 'Texture', 'Sand', 'Silt', 'Clay',]
more_feature_list.append(RS+WE+PH+LO+SO)

# %%
metric_list = []
for i in range(5):
    for year in range(2014,2022):
            shap_values_train,shap_values_test,metric_list = yield_predictor(data, test_year=[year], N=10, experiment = 'GDT', croptype = crop_type, model = ['XGBoost'], verbose = 0,
                        result = True, seed = 99, feature_list = featurelist, n_features = 500, metric_list = metric_list, 
                        result_dir = 'D:/毕业大论文/结果/特征组合结果/多因子结果/',feature_name = more_feature_list[i],feature_type = 'more_feature',col = i)
        
name = ['feature','seed', 'croptype', 'test_year', 'model', 'Train_years', 'RMSE', 'R2']
print(metric_list)
metric_df = pd.DataFrame(columns = name, data=metric_list)
metric_df.to_csv('D:/毕业大论文/结果/特征组合结果/多因子结果/' + crop_type +'_预测指标.csv',header=True)
# Out:
# feature name: 0 seed: 99 croptype: maize   test_year: 2014   model: XGBoost   experiment: GDT n_feature： 500
# 540
# 546
# The foluma of de-trend the yield: yield_new = yield - 0.117×year + 9.097 - (-226.754)
# 2023-03-15 [2014] XGBoost 【Train_RMSE: 0.06, Train_R2: 1.00, Test_RMSE: 0.8829, Test_R2: 0.73】
# feature name: 0 seed: 99 croptype: maize   test_year: 2015   model: XGBoost   experiment: GDT n_feature： 500
# 540
# 546
# The foluma of de-trend the yield: yield_new = yield - 0.124×year + 9.205 - (-240.281)
# 2023-03-15 [2015] XGBoost 【Train_RMSE: 0.05, Train_R2: 1.00, Test_RMSE: 0.9955, Test_R2: 0.66】
# feature name: 0 seed: 99 croptype: maize   test_year: 2016   model: XGBoost   experiment: GDT n_feature： 500
# 540
# 546
# The foluma of de-trend the yield: yield_new = yield - 0.133×year + 9.360 - (-257.905)
# 2023-03-15 [2016] XGBoost 【Train_RMSE: 0.05, Train_R2: 1.00, Test_RMSE: 0.9180, Test_R2: 0.69】
# feature name: 0 seed: 99 croptype: maize   test_year: 2017   model: XGBoost   experiment: GDT n_feature： 500
# 540
# 546
# The foluma of de-trend the yield: yield_new = yield - 0.146×year + 9.553 - (-284.378)
# 2023-03-15 [2017] XGBoost 【Train_RMSE: 0.05, Train_R2: 1.00, Test_RMSE: 1.0904, Test_R2: 0.64】
# feature name: 0 seed: 99 croptype: maize   test_year: 2018   model: XGBoost   experiment: GDT n_feature： 500
# 540
# 546
# The foluma of de-trend the yield: yield_new = yield - 0.158×year + 9.770 - (-308.861)
# 2023-03-15 [2018] XGBoost 【Train_RMSE: 0.04, Train_R2: 1.00, Test_RMSE: 1.0193, Test_R2: 0.69】
# feature name: 0 seed: 99 croptype: maize   test_year: 2019   model: XGBoost   experiment: GDT n_feature： 500
# 540
# 546
# The foluma of de-trend the yield: yield_new = yield - 0.153×year + 9.946 - (-298.934)
# 2023-03-15 [2019] XGBoost 【Train_RMSE: 0.04, Train_R2: 1.00, Test_RMSE: 0.9181, Test_R2: 0.63】
# feature name: 0 seed: 99 croptype: maize   test_year: 2020   model: XGBoost   experiment: GDT n_feature： 500
# 540
# 546
# The foluma of de-trend the yield: yield_new = yield - 0.155×year + 9.982 - (-302.407)
# 2023-03-15 [2020] XGBoost 【Train_RMSE: 0.04, Train_R2: 1.00, Test_RMSE: 1.0124, Test_R2: 0.63】
# feature name: 0 seed: 99 croptype: maize   test_year: 2021   model: XGBoost   experiment: GDT n_feature： 500
# 540
# 546
# The foluma of de-trend the yield: yield_new = yield - 0.158×year + 10.121 - (-307.579)
# 2023-03-15 [2021] XGBoost 【Train_RMSE: 0.03, Train_R2: 1.00, Test_RMSE: 1.2729, Test_R2: 0.73】
# feature name: 1 seed: 99 croptype: maize   test_year: 2014   model: XGBoost   experiment: GDT n_feature： 500
# 999
# 1005
# The foluma of de-trend the yield: yield_new = yield - 0.117×year + 9.097 - (-226.754)
# 2023-03-15 [2014] XGBoost 【Train_RMSE: 0.06, Train_R2: 1.00, Test_RMSE: 0.8304, Test_R2: 0.77】
# feature name: 1 seed: 99 croptype: maize   test_year: 2015   model: XGBoost   experiment: GDT n_feature： 500
# 999
# 1005
# The foluma of de-trend the yield: yield_new = yield - 0.124×year + 9.205 - (-240.281)
# 2023-03-15 [2015] XGBoost 【Train_RMSE: 0.05, Train_R2: 1.00, Test_RMSE: 0.9284, Test_R2: 0.70】
# feature name: 1 seed: 99 croptype: maize   test_year: 2016   model: XGBoost   experiment: GDT n_feature： 500
# 999
# 1005
# The foluma of de-trend the yield: yield_new = yield - 0.133×year + 9.360 - (-257.905)
# 2023-03-15 [2016] XGBoost 【Train_RMSE: 0.05, Train_R2: 1.00, Test_RMSE: 0.8229, Test_R2: 0.75】
# feature name: 1 seed: 99 croptype: maize   test_year: 2017   model: XGBoost   experiment: GDT n_feature： 500
# 999
# 1005
# The foluma of de-trend the yield: yield_new = yield - 0.146×year + 9.553 - (-284.378)
# 2023-03-15 [2017] XGBoost 【Train_RMSE: 0.05, Train_R2: 1.00, Test_RMSE: 1.0903, Test_R2: 0.64】
# feature name: 1 seed: 99 croptype: maize   test_year: 2018   model: XGBoost   experiment: GDT n_feature： 500
# 999
# 1005
# The foluma of de-trend the yield: yield_new = yield - 0.158×year + 9.770 - (-308.861)
# 2023-03-15 [2018] XGBoost 【Train_RMSE: 0.04, Train_R2: 1.00, Test_RMSE: 0.9887, Test_R2: 0.71】
# feature name: 1 seed: 99 croptype: maize   test_year: 2019   model: XGBoost   experiment: GDT n_feature： 500
# 999
# 1005
# The foluma of de-trend the yield: yield_new = yield - 0.153×year + 9.946 - (-298.934)
# 2023-03-15 [2019] XGBoost 【Train_RMSE: 0.04, Train_R2: 1.00, Test_RMSE: 0.9413, Test_R2: 0.61】
# feature name: 1 seed: 99 croptype: maize   test_year: 2020   model: XGBoost   experiment: GDT n_feature： 500
# 999
# 1005
# The foluma of de-trend the yield: yield_new = yield - 0.155×year + 9.982 - (-302.407)
# 2023-03-15 [2020] XGBoost 【Train_RMSE: 0.04, Train_R2: 1.00, Test_RMSE: 0.9579, Test_R2: 0.67】
# feature name: 1 seed: 99 croptype: maize   test_year: 2021   model: XGBoost   experiment: GDT n_feature： 500
# 999
# 1005
# The foluma of de-trend the yield: yield_new = yield - 0.158×year + 10.121 - (-307.579)
# 2023-03-15 [2021] XGBoost 【Train_RMSE: 0.03, Train_R2: 1.00, Test_RMSE: 1.0690, Test_R2: 0.81】
# feature name: 2 seed: 99 croptype: maize   test_year: 2014   model: XGBoost   experiment: GDT n_feature： 500
# 1237
# 1243
# The foluma of de-trend the yield: yield_new = yield - 0.117×year + 9.097 - (-226.754)
# 2023-03-15 [2014] XGBoost 【Train_RMSE: 0.05, Train_R2: 1.00, Test_RMSE: 0.9091, Test_R2: 0.72】
# feature name: 2 seed: 99 croptype: maize   test_year: 2015   model: XGBoost   experiment: GDT n_feature： 500
# 1237
# 1243
# The foluma of de-trend the yield: yield_new = yield - 0.124×year + 9.205 - (-240.281)
# 2023-03-15 [2015] XGBoost 【Train_RMSE: 0.04, Train_R2: 1.00, Test_RMSE: 0.8891, Test_R2: 0.73】
# feature name: 2 seed: 99 croptype: maize   test_year: 2016   model: XGBoost   experiment: GDT n_feature： 500
# 1237
# 1243
# The foluma of de-trend the yield: yield_new = yield - 0.133×year + 9.360 - (-257.905)
# 2023-03-15 [2016] XGBoost 【Train_RMSE: 0.03, Train_R2: 1.00, Test_RMSE: 0.8478, Test_R2: 0.74】
# feature name: 2 seed: 99 croptype: maize   test_year: 2017   model: XGBoost   experiment: GDT n_feature： 500
# 1237
# 1243
# The foluma of de-trend the yield: yield_new = yield - 0.146×year + 9.553 - (-284.378)
# 2023-03-15 [2017] XGBoost 【Train_RMSE: 0.04, Train_R2: 1.00, Test_RMSE: 1.0177, Test_R2: 0.68】
# feature name: 2 seed: 99 croptype: maize   test_year: 2018   model: XGBoost   experiment: GDT n_feature： 500
# 1237
# 1243
# The foluma of de-trend the yield: yield_new = yield - 0.158×year + 9.770 - (-308.861)
# 2023-03-15 [2018] XGBoost 【Train_RMSE: 0.03, Train_R2: 1.00, Test_RMSE: 0.9808, Test_R2: 0.72】
# feature name: 2 seed: 99 croptype: maize   test_year: 2019   model: XGBoost   experiment: GDT n_feature： 500
# 1237
# 1243
# The foluma of de-trend the yield: yield_new = yield - 0.153×year + 9.946 - (-298.934)
# 2023-03-15 [2019] XGBoost 【Train_RMSE: 0.03, Train_R2: 1.00, Test_RMSE: 0.9092, Test_R2: 0.64】
# feature name: 2 seed: 99 croptype: maize   test_year: 2020   model: XGBoost   experiment: GDT n_feature： 500
# 1237
# 1243
# The foluma of de-trend the yield: yield_new = yield - 0.155×year + 9.982 - (-302.407)
# 2023-03-15 [2020] XGBoost 【Train_RMSE: 0.03, Train_R2: 1.00, Test_RMSE: 1.0106, Test_R2: 0.63】
# feature name: 2 seed: 99 croptype: maize   test_year: 2021   model: XGBoost   experiment: GDT n_feature： 500
# 1237
# 1243
# The foluma of de-trend the yield: yield_new = yield - 0.158×year + 10.121 - (-307.579)
# 2023-03-15 [2021] XGBoost 【Train_RMSE: 0.03, Train_R2: 1.00, Test_RMSE: 1.1275, Test_R2: 0.79】
# feature name: 3 seed: 99 croptype: maize   test_year: 2014   model: XGBoost   experiment: GDT n_feature： 500
# 1251
# 1257
# The foluma of de-trend the yield: yield_new = yield - 0.117×year + 9.097 - (-226.754)
# 2023-03-15 [2014] XGBoost 【Train_RMSE: 0.04, Train_R2: 1.00, Test_RMSE: 0.8702, Test_R2: 0.74】
# feature name: 3 seed: 99 croptype: maize   test_year: 2015   model: XGBoost   experiment: GDT n_feature： 500
# 1251
# 1257
# The foluma of de-trend the yield: yield_new = yield - 0.124×year + 9.205 - (-240.281)
# 2023-03-15 [2015] XGBoost 【Train_RMSE: 0.03, Train_R2: 1.00, Test_RMSE: 0.8583, Test_R2: 0.75】
# feature name: 3 seed: 99 croptype: maize   test_year: 2016   model: XGBoost   experiment: GDT n_feature： 500
# 1251
# 1257
# The foluma of de-trend the yield: yield_new = yield - 0.133×year + 9.360 - (-257.905)
# 2023-03-15 [2016] XGBoost 【Train_RMSE: 0.03, Train_R2: 1.00, Test_RMSE: 0.8891, Test_R2: 0.71】
# feature name: 3 seed: 99 croptype: maize   test_year: 2017   model: XGBoost   experiment: GDT n_feature： 500
# 1251
# 1257
# The foluma of de-trend the yield: yield_new = yield - 0.146×year + 9.553 - (-284.378)
# 2023-03-15 [2017] XGBoost 【Train_RMSE: 0.03, Train_R2: 1.00, Test_RMSE: 0.9961, Test_R2: 0.70】
# feature name: 3 seed: 99 croptype: maize   test_year: 2018   model: XGBoost   experiment: GDT n_feature： 500
# 1251
# 1257
# The foluma of de-trend the yield: yield_new = yield - 0.158×year + 9.770 - (-308.861)
# 2023-03-15 [2018] XGBoost 【Train_RMSE: 0.03, Train_R2: 1.00, Test_RMSE: 0.9739, Test_R2: 0.72】
# feature name: 3 seed: 99 croptype: maize   test_year: 2019   model: XGBoost   experiment: GDT n_feature： 500
# 1251
# 1257
# The foluma of de-trend the yield: yield_new = yield - 0.153×year + 9.946 - (-298.934)
# 2023-03-15 [2019] XGBoost 【Train_RMSE: 0.03, Train_R2: 1.00, Test_RMSE: 0.8726, Test_R2: 0.67】
# feature name: 3 seed: 99 croptype: maize   test_year: 2020   model: XGBoost   experiment: GDT n_feature： 500
# 1251
# 1257
# The foluma of de-trend the yield: yield_new = yield - 0.155×year + 9.982 - (-302.407)
# 2023-03-15 [2020] XGBoost 【Train_RMSE: 0.03, Train_R2: 1.00, Test_RMSE: 0.9919, Test_R2: 0.65】
# feature name: 3 seed: 99 croptype: maize   test_year: 2021   model: XGBoost   experiment: GDT n_feature： 500
# 1251
# 1257
# The foluma of de-trend the yield: yield_new = yield - 0.158×year + 10.121 - (-307.579)
# 2023-03-15 [2021] XGBoost 【Train_RMSE: 0.03, Train_R2: 1.00, Test_RMSE: 1.0784, Test_R2: 0.81】
# feature name: 4 seed: 99 croptype: maize   test_year: 2014   model: XGBoost   experiment: GDT n_feature： 500
# 1268
# 1274
# The foluma of de-trend the yield: yield_new = yield - 0.117×year + 9.097 - (-226.754)
# 2023-03-15 [2014] XGBoost 【Train_RMSE: 0.03, Train_R2: 1.00, Test_RMSE: 0.8108, Test_R2: 0.78】
# feature name: 4 seed: 99 croptype: maize   test_year: 2015   model: XGBoost   experiment: GDT n_feature： 500
# 1268
# 1274
# The foluma of de-trend the yield: yield_new = yield - 0.124×year + 9.205 - (-240.281)
# 2023-03-15 [2015] XGBoost 【Train_RMSE: 0.03, Train_R2: 1.00, Test_RMSE: 0.8459, Test_R2: 0.75】
# feature name: 4 seed: 99 croptype: maize   test_year: 2016   model: XGBoost   experiment: GDT n_feature： 500
# 1268
# 1274
# The foluma of de-trend the yield: yield_new = yield - 0.133×year + 9.360 - (-257.905)
# 2023-03-15 [2016] XGBoost 【Train_RMSE: 0.03, Train_R2: 1.00, Test_RMSE: 0.8300, Test_R2: 0.75】
# feature name: 4 seed: 99 croptype: maize   test_year: 2017   model: XGBoost   experiment: GDT n_feature： 500
# 1268
# 1274
# The foluma of de-trend the yield: yield_new = yield - 0.146×year + 9.553 - (-284.378)
# 2023-03-15 [2017] XGBoost 【Train_RMSE: 0.03, Train_R2: 1.00, Test_RMSE: 0.9244, Test_R2: 0.74】
# feature name: 4 seed: 99 croptype: maize   test_year: 2018   model: XGBoost   experiment: GDT n_feature： 500
# 1268
# 1274
# The foluma of de-trend the yield: yield_new = yield - 0.158×year + 9.770 - (-308.861)
# 2023-03-15 [2018] XGBoost 【Train_RMSE: 0.03, Train_R2: 1.00, Test_RMSE: 0.9192, Test_R2: 0.75】
# feature name: 4 seed: 99 croptype: maize   test_year: 2019   model: XGBoost   experiment: GDT n_feature： 500
# 1268
# 1274
# The foluma of de-trend the yield: yield_new = yield - 0.153×year + 9.946 - (-298.934)
# 2023-03-15 [2019] XGBoost 【Train_RMSE: 0.03, Train_R2: 1.00, Test_RMSE: 0.8015, Test_R2: 0.72】
# feature name: 4 seed: 99 croptype: maize   test_year: 2020   model: XGBoost   experiment: GDT n_feature： 500
# 1268
# 1274
# The foluma of de-trend the yield: yield_new = yield - 0.155×year + 9.982 - (-302.407)
# 2023-03-15 [2020] XGBoost 【Train_RMSE: 0.03, Train_R2: 1.00, Test_RMSE: 0.9844, Test_R2: 0.65】
# feature name: 4 seed: 99 croptype: maize   test_year: 2021   model: XGBoost   experiment: GDT n_feature： 500
# 1268
# 1274
# The foluma of de-trend the yield: yield_new = yield - 0.158×year + 10.121 - (-307.579)
# 2023-03-15 [2021] XGBoost 【Train_RMSE: 0.03, Train_R2: 1.00, Test_RMSE: 1.0337, Test_R2: 0.82】
# [[0, 99, 'maize', 2014, 'XGBoost', 10, 0.8828965204876266, 0.7349435730999867], [0, 99, 'maize', 2015, 'XGBoost', 10, 0.995508075495662, 0.6587555579593931], [0, 99, 'maize', 2016, 'XGBoost', 10, 0.9179858683109752, 0.6904674007570215], [0, 99, 'maize', 2017, 'XGBoost', 10, 1.0903800887359196, 0.638265724579625], [0, 99, 'maize', 2018, 'XGBoost', 10, 1.0192927942671621, 0.6942799480071489], [0, 99, 'maize', 2019, 'XGBoost', 10, 0.9180747220360869, 0.6314455737631895], [0, 99, 'maize', 2020, 'XGBoost', 10, 1.0124229293558413, 0.6305629028048316], [0, 99, 'maize', 2021, 'XGBoost', 10, 1.27294843730481, 0.7324833670916742], [1, 99, 'maize', 2014, 'XGBoost', 10, 0.8304360678175955, 0.7655063237194055], [1, 99, 'maize', 2015, 'XGBoost', 10, 0.9284089516885811, 0.7032063188348433], [1, 99, 'maize', 2016, 'XGBoost', 10, 0.8228645157008313, 0.751291245410277], [1, 99, 'maize', 2017, 'XGBoost', 10, 1.0902514136685795, 0.6383510956099419], [1, 99, 'maize', 2018, 'XGBoost', 10, 0.9886617903771592, 0.7123783876163454], [1, 99, 'maize', 2019, 'XGBoost', 10, 0.9413291936301211, 0.6125384360080963], [1, 99, 'maize', 2020, 'XGBoost', 10, 0.9578617943956069, 0.6693090874776207], [1, 99, 'maize', 2021, 'XGBoost', 10, 1.0689938616943335, 0.8113401052057231], [2, 99, 'maize', 2014, 'XGBoost', 10, 0.9091437329080161, 0.7189498462220589], [2, 99, 'maize', 2015, 'XGBoost', 10, 0.8891107971634713, 0.7278002133767298], [2, 99, 'maize', 2016, 'XGBoost', 10, 0.8477780260186967, 0.736003168333071], [2, 99, 'maize', 2017, 'XGBoost', 10, 1.017740080665391, 0.684857051996065], [2, 99, 'maize', 2018, 'XGBoost', 10, 0.980772808438179, 0.7169502014957474], [2, 99, 'maize', 2019, 'XGBoost', 10, 0.9091802429076753, 0.6385522289256693], [2, 99, 'maize', 2020, 'XGBoost', 10, 1.0106438283284624, 0.6318601638665865], [2, 99, 'maize', 2021, 'XGBoost', 10, 1.1275444521142763, 0.7901076983845371], [3, 99, 'maize', 2014, 'XGBoost', 10, 0.87018612306118, 0.7425202758424212], [3, 99, 'maize', 2015, 'XGBoost', 10, 0.8582800743203911, 0.7463504640041676], [3, 99, 'maize', 2016, 'XGBoost', 10, 0.8890677110449919, 0.7096618673724985], [3, 99, 'maize', 2017, 'XGBoost', 10, 0.9960969868699364, 0.6981180896670882], [3, 99, 'maize', 2018, 'XGBoost', 10, 0.9738600511993297, 0.7209261661765952], [3, 99, 'maize', 2019, 'XGBoost', 10, 0.8726294313968472, 0.6670298631805403], [3, 99, 'maize', 2020, 'XGBoost', 10, 0.9919077026991432, 0.6453833818448274], [3, 99, 'maize', 2021, 'XGBoost', 10, 1.078439809153443, 0.8079912648157074], [4, 99, 'maize', 2014, 'XGBoost', 10, 0.8107926359097504, 0.7764687124484532], [4, 99, 'maize', 2015, 'XGBoost', 10, 0.8459059408635261, 0.7536116540673444], [4, 99, 'maize', 2016, 'XGBoost', 10, 0.8300432232646868, 0.7469328234065928], [4, 99, 'maize', 2017, 'XGBoost', 10, 0.9244163133870539, 0.7400025798023371], [4, 99, 'maize', 2018, 'XGBoost', 10, 0.9191929685153387, 0.7513780870504773], [4, 99, 'maize', 2019, 'XGBoost', 10, 0.8015386001295647, 0.7190723701311803], [4, 99, 'maize', 2020, 'XGBoost', 10, 0.9844121480610842, 0.6507225987609686], [4, 99, 'maize', 2021, 'XGBoost', 10, 1.0336847413249735, 0.8235972399052464]]

# %% [markdown]
# ### 单因子特征结果-大豆

# %%
# 2014-2021，每10年预测一年
data = read_data('D:/毕业大论文/数据/input_soybean_rename.csv')
featurelist = read_data('D:/毕业大论文/结果/SHAP值结果/soybean/average_feature_importance.csv')

# %%
# 特征组合列表
all_features = data.columns.tolist()
one_feature_list = []
one_feature_list = one_feature_list+['EVI_Podding','Latitude','PAWS','SPI30d_Early Sep.','PIC']
one_feature_list
#     sub_list =  sub_list+static_list
#     name_list = [element for element in all_features if any(substring in element for substring in sub_list)]
# Out:
# ['EVI_Podding', 'Latitude', 'PAWS', 'SPI30d_Early Sep.', 'PIC']

# %%
# 单因子预测 大豆
crop_type = 'soybean'
metric_list = []
for i in range(5):
    for year in range(2014,2022):
            shap_values_train,shap_values_test,metric_list = yield_predictor(data, test_year=[year], N=10, experiment = 'GDT', croptype = crop_type, model = ['XGBoost'], verbose = 0,
                        result = True, seed = 99, feature_list = featurelist, n_features = 500, metric_list = metric_list, 
                        result_dir = 'D:/毕业大论文/结果/特征组合结果/单因子结果/',feature_name = one_feature_list[i])
        
name = ['feature','seed', 'croptype', 'test_year', 'model', 'Train_years', 'RMSE', 'R2']
print(metric_list)
metric_df = pd.DataFrame(columns = name, data=metric_list)
metric_df.to_csv('D:/毕业大论文/结果/特征组合结果/单因子结果/' + crop_type +'_预测指标.csv',header=True)

# %% [markdown]
# ### 单因子特征结果-玉米

# %%
# 2014-2021，每10年预测一年
data = read_data('D:/毕业大论文/数据/input_maize_rename.csv')
featurelist = read_data('D:/毕业大论文/结果/SHAP值结果/maize/average_feature_importance.csv')

# %%
# 特征组合列表
all_features = data.columns.tolist()
one_feature_list = []
one_feature_list = one_feature_list+['LSWI_Dough','EVI_Dough','Latitude','pH','EDDI14d_Late Oct.','AREA_Irrigated']
one_feature_list
# Out:
# ['LSWI_Dough',
#  'EVI_Dough',
#  'Latitude',
#  'pH',
#  'EDDI14d_Late Oct.',
#  'AREA_Irrigated']

# %%
# 无特征工程预测 玉米
crop_type = 'maize'
metric_list = []
for i in range(6):
    for year in range(2014,2022):
            shap_values_train,shap_values_test,metric_list = yield_predictor(data, test_year=[year], N=10, experiment = 'GDT', croptype = crop_type, model = ['XGBoost'], verbose = 0,
                        result = True, seed = 99, feature_list = featurelist, n_features = 500, metric_list = metric_list, 
                        result_dir = 'D:/毕业大论文/结果/特征组合结果/单因子结果/',feature_name = one_feature_list[i])
        
name = ['feature','seed', 'croptype', 'test_year', 'model', 'Train_years', 'RMSE', 'R2']
print(metric_list)
metric_df = pd.DataFrame(columns = name, data=metric_list)
metric_df.to_csv('D:/毕业大论文/结果/特征组合结果/单因子结果/' + crop_type +'_预测指标.csv',header=True)
# Out:
# feature name: LSWI_Dough seed: 99 croptype: maize   test_year: 2014   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.117×year + 9.097 - (-226.754)
# 2023-03-12 [2014] XGBoost 【Train_RMSE: 1.13, Train_R2: 0.69, Test_RMSE: 1.3936, Test_R2: 0.34】
# feature name: LSWI_Dough seed: 99 croptype: maize   test_year: 2015   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.124×year + 9.205 - (-240.281)
# 2023-03-12 [2015] XGBoost 【Train_RMSE: 1.09, Train_R2: 0.70, Test_RMSE: 1.2390, Test_R2: 0.47】
# feature name: LSWI_Dough seed: 99 croptype: maize   test_year: 2016   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.133×year + 9.360 - (-257.905)
# 2023-03-12 [2016] XGBoost 【Train_RMSE: 1.07, Train_R2: 0.71, Test_RMSE: 1.2245, Test_R2: 0.45】
# feature name: LSWI_Dough seed: 99 croptype: maize   test_year: 2017   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.146×year + 9.553 - (-284.378)
# 2023-03-12 [2017] XGBoost 【Train_RMSE: 1.04, Train_R2: 0.73, Test_RMSE: 1.2390, Test_R2: 0.53】
# feature name: LSWI_Dough seed: 99 croptype: maize   test_year: 2018   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.158×year + 9.770 - (-308.861)
# 2023-03-12 [2018] XGBoost 【Train_RMSE: 1.02, Train_R2: 0.74, Test_RMSE: 1.2893, Test_R2: 0.51】
# feature name: LSWI_Dough seed: 99 croptype: maize   test_year: 2019   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.153×year + 9.946 - (-298.934)
# 2023-03-12 [2019] XGBoost 【Train_RMSE: 1.02, Train_R2: 0.75, Test_RMSE: 1.0957, Test_R2: 0.48】
# feature name: LSWI_Dough seed: 99 croptype: maize   test_year: 2020   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.155×year + 9.982 - (-302.407)
# 2023-03-12 [2020] XGBoost 【Train_RMSE: 1.00, Train_R2: 0.76, Test_RMSE: 1.2850, Test_R2: 0.40】
# feature name: LSWI_Dough seed: 99 croptype: maize   test_year: 2021   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.158×year + 10.121 - (-307.579)
# 2023-03-12 [2021] XGBoost 【Train_RMSE: 0.98, Train_R2: 0.77, Test_RMSE: 1.4524, Test_R2: 0.65】
# feature name: EVI_Dough seed: 99 croptype: maize   test_year: 2014   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.117×year + 9.097 - (-226.754)
# 2023-03-12 [2014] XGBoost 【Train_RMSE: 1.10, Train_R2: 0.71, Test_RMSE: 1.1653, Test_R2: 0.54】
# feature name: EVI_Dough seed: 99 croptype: maize   test_year: 2015   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.124×year + 9.205 - (-240.281)
# 2023-03-12 [2015] XGBoost 【Train_RMSE: 1.06, Train_R2: 0.72, Test_RMSE: 1.2395, Test_R2: 0.47】
# feature name: EVI_Dough seed: 99 croptype: maize   test_year: 2016   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.133×year + 9.360 - (-257.905)
# 2023-03-12 [2016] XGBoost 【Train_RMSE: 1.03, Train_R2: 0.73, Test_RMSE: 1.3773, Test_R2: 0.30】
# feature name: EVI_Dough seed: 99 croptype: maize   test_year: 2017   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.146×year + 9.553 - (-284.378)
# 2023-03-12 [2017] XGBoost 【Train_RMSE: 1.04, Train_R2: 0.73, Test_RMSE: 1.2674, Test_R2: 0.51】
# feature name: EVI_Dough seed: 99 croptype: maize   test_year: 2018   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.158×year + 9.770 - (-308.861)
# 2023-03-12 [2018] XGBoost 【Train_RMSE: 1.03, Train_R2: 0.73, Test_RMSE: 1.2780, Test_R2: 0.52】
# feature name: EVI_Dough seed: 99 croptype: maize   test_year: 2019   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.153×year + 9.946 - (-298.934)
# 2023-03-12 [2019] XGBoost 【Train_RMSE: 1.02, Train_R2: 0.75, Test_RMSE: 1.1521, Test_R2: 0.42】
# feature name: EVI_Dough seed: 99 croptype: maize   test_year: 2020   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.155×year + 9.982 - (-302.407)
# 2023-03-12 [2020] XGBoost 【Train_RMSE: 0.99, Train_R2: 0.76, Test_RMSE: 1.2842, Test_R2: 0.41】
# feature name: EVI_Dough seed: 99 croptype: maize   test_year: 2021   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.158×year + 10.121 - (-307.579)
# 2023-03-12 [2021] XGBoost 【Train_RMSE: 0.99, Train_R2: 0.76, Test_RMSE: 1.4661, Test_R2: 0.65】
# feature name: Latitude seed: 99 croptype: maize   test_year: 2014   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.117×year + 9.097 - (-226.754)
# 2023-03-12 [2014] XGBoost 【Train_RMSE: 1.42, Train_R2: 0.51, Test_RMSE: 1.5331, Test_R2: 0.20】
# feature name: Latitude seed: 99 croptype: maize   test_year: 2015   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.124×year + 9.205 - (-240.281)
# 2023-03-12 [2015] XGBoost 【Train_RMSE: 1.42, Train_R2: 0.50, Test_RMSE: 1.2373, Test_R2: 0.47】
# feature name: Latitude seed: 99 croptype: maize   test_year: 2016   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.133×year + 9.360 - (-257.905)
# 2023-03-12 [2016] XGBoost 【Train_RMSE: 1.42, Train_R2: 0.49, Test_RMSE: 1.3586, Test_R2: 0.32】
# feature name: Latitude seed: 99 croptype: maize   test_year: 2017   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.146×year + 9.553 - (-284.378)
# 2023-03-12 [2017] XGBoost 【Train_RMSE: 1.44, Train_R2: 0.48, Test_RMSE: 1.1952, Test_R2: 0.57】
# feature name: Latitude seed: 99 croptype: maize   test_year: 2018   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.158×year + 9.770 - (-308.861)
# 2023-03-12 [2018] XGBoost 【Train_RMSE: 1.44, Train_R2: 0.48, Test_RMSE: 1.2745, Test_R2: 0.52】
# feature name: Latitude seed: 99 croptype: maize   test_year: 2019   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.153×year + 9.946 - (-298.934)
# 2023-03-12 [2019] XGBoost 【Train_RMSE: 1.47, Train_R2: 0.48, Test_RMSE: 0.9623, Test_R2: 0.60】
# feature name: Latitude seed: 99 croptype: maize   test_year: 2020   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.155×year + 9.982 - (-302.407)
# 2023-03-12 [2020] XGBoost 【Train_RMSE: 1.46, Train_R2: 0.48, Test_RMSE: 1.1620, Test_R2: 0.51】
# feature name: Latitude seed: 99 croptype: maize   test_year: 2021   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.158×year + 10.121 - (-307.579)
# 2023-03-12 [2021] XGBoost 【Train_RMSE: 1.45, Train_R2: 0.49, Test_RMSE: 1.4770, Test_R2: 0.64】
# feature name: pH seed: 99 croptype: maize   test_year: 2014   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.117×year + 9.097 - (-226.754)
# 2023-03-12 [2014] XGBoost 【Train_RMSE: 1.42, Train_R2: 0.51, Test_RMSE: 1.5221, Test_R2: 0.21】
# feature name: pH seed: 99 croptype: maize   test_year: 2015   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.124×year + 9.205 - (-240.281)
# 2023-03-12 [2015] XGBoost 【Train_RMSE: 1.41, Train_R2: 0.50, Test_RMSE: 1.2344, Test_R2: 0.48】
# feature name: pH seed: 99 croptype: maize   test_year: 2016   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.133×year + 9.360 - (-257.905)
# 2023-03-12 [2016] XGBoost 【Train_RMSE: 1.42, Train_R2: 0.49, Test_RMSE: 1.3321, Test_R2: 0.35】
# feature name: pH seed: 99 croptype: maize   test_year: 2017   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.146×year + 9.553 - (-284.378)
# 2023-03-12 [2017] XGBoost 【Train_RMSE: 1.43, Train_R2: 0.48, Test_RMSE: 1.1686, Test_R2: 0.58】
# feature name: pH seed: 99 croptype: maize   test_year: 2018   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.158×year + 9.770 - (-308.861)
# 2023-03-12 [2018] XGBoost 【Train_RMSE: 1.43, Train_R2: 0.48, Test_RMSE: 1.2572, Test_R2: 0.53】
# feature name: pH seed: 99 croptype: maize   test_year: 2019   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.153×year + 9.946 - (-298.934)
# 2023-03-12 [2019] XGBoost 【Train_RMSE: 1.46, Train_R2: 0.48, Test_RMSE: 0.9935, Test_R2: 0.57】
# feature name: pH seed: 99 croptype: maize   test_year: 2020   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.155×year + 9.982 - (-302.407)
# 2023-03-12 [2020] XGBoost 【Train_RMSE: 1.44, Train_R2: 0.49, Test_RMSE: 1.0782, Test_R2: 0.58】
# feature name: pH seed: 99 croptype: maize   test_year: 2021   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.158×year + 10.121 - (-307.579)
# 2023-03-12 [2021] XGBoost 【Train_RMSE: 1.44, Train_R2: 0.50, Test_RMSE: 1.4646, Test_R2: 0.65】
# feature name: EDDI14d_Late Oct. seed: 99 croptype: maize   test_year: 2014   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.117×year + 9.097 - (-226.754)
# 2023-03-12 [2014] XGBoost 【Train_RMSE: 1.49, Train_R2: 0.47, Test_RMSE: 2.1230, Test_R2: -0.53】
# feature name: EDDI14d_Late Oct. seed: 99 croptype: maize   test_year: 2015   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.124×year + 9.205 - (-240.281)
# 2023-03-12 [2015] XGBoost 【Train_RMSE: 1.45, Train_R2: 0.47, Test_RMSE: 2.2767, Test_R2: -0.78】
# feature name: EDDI14d_Late Oct. seed: 99 croptype: maize   test_year: 2016   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.133×year + 9.360 - (-257.905)
# 2023-03-12 [2016] XGBoost 【Train_RMSE: 1.44, Train_R2: 0.48, Test_RMSE: 1.9221, Test_R2: -0.36】
# feature name: EDDI14d_Late Oct. seed: 99 croptype: maize   test_year: 2017   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.146×year + 9.553 - (-284.378)
# 2023-03-12 [2017] XGBoost 【Train_RMSE: 1.43, Train_R2: 0.48, Test_RMSE: 2.3773, Test_R2: -0.72】
# feature name: EDDI14d_Late Oct. seed: 99 croptype: maize   test_year: 2018   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.158×year + 9.770 - (-308.861)
# 2023-03-12 [2018] XGBoost 【Train_RMSE: 1.43, Train_R2: 0.49, Test_RMSE: 1.9604, Test_R2: -0.13】
# feature name: EDDI14d_Late Oct. seed: 99 croptype: maize   test_year: 2019   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.153×year + 9.946 - (-298.934)
# 2023-03-12 [2019] XGBoost 【Train_RMSE: 1.45, Train_R2: 0.49, Test_RMSE: 1.8006, Test_R2: -0.42】
# feature name: EDDI14d_Late Oct. seed: 99 croptype: maize   test_year: 2020   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.155×year + 9.982 - (-302.407)
# 2023-03-12 [2020] XGBoost 【Train_RMSE: 1.46, Train_R2: 0.48, Test_RMSE: 1.8922, Test_R2: -0.29】
# feature name: EDDI14d_Late Oct. seed: 99 croptype: maize   test_year: 2021   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.158×year + 10.121 - (-307.579)
# 2023-03-12 [2021] XGBoost 【Train_RMSE: 1.49, Train_R2: 0.47, Test_RMSE: 2.6340, Test_R2: -0.15】
# feature name: AREA_Irrigated seed: 99 croptype: maize   test_year: 2014   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.117×year + 9.097 - (-226.754)
# 2023-03-12 [2014] XGBoost 【Train_RMSE: 1.55, Train_R2: 0.42, Test_RMSE: 1.6273, Test_R2: 0.10】
# feature name: AREA_Irrigated seed: 99 croptype: maize   test_year: 2015   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.124×year + 9.205 - (-240.281)
# 2023-03-12 [2015] XGBoost 【Train_RMSE: 1.53, Train_R2: 0.42, Test_RMSE: 1.8453, Test_R2: -0.17】
# feature name: AREA_Irrigated seed: 99 croptype: maize   test_year: 2016   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.133×year + 9.360 - (-257.905)
# 2023-03-12 [2016] XGBoost 【Train_RMSE: 1.53, Train_R2: 0.41, Test_RMSE: 1.5914, Test_R2: 0.07】
# feature name: AREA_Irrigated seed: 99 croptype: maize   test_year: 2017   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.146×year + 9.553 - (-284.378)
# 2023-03-12 [2017] XGBoost 【Train_RMSE: 1.54, Train_R2: 0.40, Test_RMSE: 2.0471, Test_R2: -0.28】
# feature name: AREA_Irrigated seed: 99 croptype: maize   test_year: 2018   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.158×year + 9.770 - (-308.861)
# 2023-03-12 [2018] XGBoost 【Train_RMSE: 1.56, Train_R2: 0.39, Test_RMSE: 1.5229, Test_R2: 0.32】
# feature name: AREA_Irrigated seed: 99 croptype: maize   test_year: 2019   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.153×year + 9.946 - (-298.934)
# 2023-03-12 [2019] XGBoost 【Train_RMSE: 1.58, Train_R2: 0.39, Test_RMSE: 1.2187, Test_R2: 0.35】
# feature name: AREA_Irrigated seed: 99 croptype: maize   test_year: 2020   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.155×year + 9.982 - (-302.407)
# 2023-03-12 [2020] XGBoost 【Train_RMSE: 1.57, Train_R2: 0.40, Test_RMSE: 1.3046, Test_R2: 0.39】
# feature name: AREA_Irrigated seed: 99 croptype: maize   test_year: 2021   model: XGBoost   experiment: GDT n_feature： 500
# 1
# 7
# The foluma of de-trend the yield: yield_new = yield - 0.158×year + 10.121 - (-307.579)
# 2023-03-12 [2021] XGBoost 【Train_RMSE: 1.57, Train_R2: 0.41, Test_RMSE: 1.7751, Test_R2: 0.48】
# [['LSWI_Dough', 99, 'maize', 2014, 'XGBoost', 10, 1.393551291838103, 0.33966450108210544], ['LSWI_Dough', 99, 'maize', 2015, 'XGBoost', 10, 1.2390228000604682, 0.47139093280140376], ['LSWI_Dough', 99, 'maize', 2016, 'XGBoost', 10, 1.2244658223432523, 0.4492839441091162], ['LSWI_Dough', 99, 'maize', 2017, 'XGBoost', 10, 1.2390134182602583, 0.5329258240614608], ['LSWI_Dough', 99, 'maize', 2018, 'XGBoost', 10, 1.2892895826046968, 0.5108670001963724], ['LSWI_Dough', 99, 'maize', 2019, 'XGBoost', 10, 1.0956616218009434, 0.47507353247802697], ['LSWI_Dough', 99, 'maize', 2020, 'XGBoost', 10, 1.2849890829488093, 0.4048650792076015], ['LSWI_Dough', 99, 'maize', 2021, 'XGBoost', 10, 1.4523870562688754, 0.6517477711304964], ['EVI_Dough', 99, 'maize', 2014, 'XGBoost', 10, 1.1652982700897767, 0.5382648550599287], ['EVI_Dough', 99, 'maize', 2015, 'XGBoost', 10, 1.2395099772647045, 0.4709751585049735], ['EVI_Dough', 99, 'maize', 2016, 'XGBoost', 10, 1.3773428445890474, 0.3031833525701533], ['EVI_Dough', 99, 'maize', 2017, 'XGBoost', 10, 1.2674144197039214, 0.5112676072887666], ['EVI_Dough', 99, 'maize', 2018, 'XGBoost', 10, 1.2779943360088093, 0.5193998801140041], ['EVI_Dough', 99, 'maize', 2019, 'XGBoost', 10, 1.1521306889400773, 0.4195710553908196], ['EVI_Dough', 99, 'maize', 2020, 'XGBoost', 10, 1.2842309918547163, 0.40556708267878927], ['EVI_Dough', 99, 'maize', 2021, 'XGBoost', 10, 1.4661223676025517, 0.6451297404998253], ['Latitude', 99, 'maize', 2014, 'XGBoost', 10, 1.533104525261745, 0.20078751485650204], ['Latitude', 99, 'maize', 2015, 'XGBoost', 10, 1.2373444287251656, 0.4728220628936123], ['Latitude', 99, 'maize', 2016, 'XGBoost', 10, 1.3585640664667458, 0.3220547060939809], ['Latitude', 99, 'maize', 2017, 'XGBoost', 10, 1.1951669940857543, 0.5653987020781024], ['Latitude', 99, 'maize', 2018, 'XGBoost', 10, 1.2745071881703627, 0.5220190422670866], ['Latitude', 99, 'maize', 2019, 'XGBoost', 10, 0.9623094313090013, 0.5950745662592374], ['Latitude', 99, 'maize', 2020, 'XGBoost', 10, 1.1619903386116603, 0.5133445488112381], ['Latitude', 99, 'maize', 2021, 'XGBoost', 10, 1.4770398444193071, 0.6398249816957001], ['pH', 99, 'maize', 2014, 'XGBoost', 10, 1.522097645670139, 0.21222216544205275], ['pH', 99, 'maize', 2015, 'XGBoost', 10, 1.2344074086279249, 0.47532176235062773], ['pH', 99, 'maize', 2016, 'XGBoost', 10, 1.3321286977288787, 0.3481813656864984], ['pH', 99, 'maize', 2017, 'XGBoost', 10, 1.1685994825308177, 0.5845055604327531], ['pH', 99, 'maize', 2018, 'XGBoost', 10, 1.2571845720367814, 0.5349238139853725], ['pH', 99, 'maize', 2019, 'XGBoost', 10, 0.9934712698864461, 0.5684250824347525], ['pH', 99, 'maize', 2020, 'XGBoost', 10, 1.0782015171934796, 0.5809976725213266], ['pH', 99, 'maize', 2021, 'XGBoost', 10, 1.464611064474124, 0.6458609756589737], ['EDDI14d_Late Oct.', 99, 'maize', 2014, 'XGBoost', 10, 2.1229546846958005, -0.5324989188058933], ['EDDI14d_Late Oct.', 99, 'maize', 2015, 'XGBoost', 10, 2.2766951385534826, -0.7847844451595127], ['EDDI14d_Late Oct.', 99, 'maize', 2016, 'XGBoost', 10, 1.9221083103375929, -0.35703208558220756], ['EDDI14d_Late Oct.', 99, 'maize', 2017, 'XGBoost', 10, 2.377342020703471, -0.7195593518404451], ['EDDI14d_Late Oct.', 99, 'maize', 2018, 'XGBoost', 10, 1.9603762876389477, -0.1308497285763066], ['EDDI14d_Late Oct.', 99, 'maize', 2019, 'XGBoost', 10, 1.8005668895021063, -0.41763390328036953], ['EDDI14d_Late Oct.', 99, 'maize', 2020, 'XGBoost', 10, 1.892226796954893, -0.2905146384637951], ['EDDI14d_Late Oct.', 99, 'maize', 2021, 'XGBoost', 10, 2.634020800372223, -0.1454273938235069], ['AREA_Irrigated', 99, 'maize', 2014, 'XGBoost', 10, 1.6273278378200908, 0.09953085496194747], ['AREA_Irrigated', 99, 'maize', 2015, 'XGBoost', 10, 1.8453210433379348, -0.17251897727279308], ['AREA_Irrigated', 99, 'maize', 2016, 'XGBoost', 10, 1.5914240887812308, 0.06973590620616232], ['AREA_Irrigated', 99, 'maize', 2017, 'XGBoost', 10, 2.0471100032380147, -0.27501765305431825], ['AREA_Irrigated', 99, 'maize', 2018, ' ...
